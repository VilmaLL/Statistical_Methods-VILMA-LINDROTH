# %%
import numpy as np

# %%
x = np.array([3, 4, 5])
y = np.array([6, 7, 8])
x+y
# Out:
# array([ 9, 11, 13])

# %%
A = np.array([[1, 1, 1],
              [2, 1, -1],
              [3, 2, 1]])
y = np.array([4, 1, 5])
A.shape, A.ndim
# Out:
# ((3, 3), 2)

# %%
x = np.linalg.inv(A) @ y
x
# Out:
# array([-3.00000000e+00,  7.00000000e+00,  1.22124533e-15])

# %%
A @ x
# Out:
# array([4., 1., 5.])

# %%
B = np.array([[1, 1, 1],
              [2, 1, -1],
              [3, 2, 0]])
np.linalg.det(B)
# Out:
# np.float64(-3.330669073875464e-16)

# %%
x = np.linalg.inv(B) @ y
B @ x
# Out:
# array([4., 0., 4.])

# %%
x = np.linalg.solve(a=A, b=y)
x, A @ x
# Out:
# (array([-3.0000000e+00,  7.0000000e+00,  4.4408921e-16]), array([4., 1., 5.]))

# %%
x = np.linalg.solve(a=B, b=y)
x, B @ x
# Out:
# (array([-0.33333333,  3.        ,  1.33333333]), array([4., 1., 5.]))

# %% [markdown]
# # Random sampling from statistical distributions

# %%
rng = np.random.default_rng()

X_int = rng.integers(100, size=100)
X_int
# Out:
# array([42,  9, 19, 12, 26, 62, 95, 96, 24, 89, 62,  7, 52, 89, 20, 29, 87,
#        87, 74, 82, 48, 21, 88, 22, 98, 65, 82, 84, 64,  6, 13, 53, 38, 19,
#         9, 31, 80, 69, 69, 19, 52, 21, 67,  5, 32, 34, 89, 85, 21, 46, 61,
#         6, 16, 59, 27, 25, 15, 15, 68, 78, 20, 76, 13, 89, 64, 54, 60, 81,
#        29, 56, 49, 63, 14, 34, 94, 48, 43, 24, 76, 60, 35, 60, 60, 41, 54,
#        38, 59,  9, 52, 58, 53, 68,  5, 23, 45, 16,  1, 19, 12, 41])

# %%
X_uniform = rng.uniform(size=100)
X_uniform
# Out:
# array([0.11969302, 0.18234502, 0.71106074, 0.23475628, 0.72727892,
#        0.34446989, 0.59090415, 0.19130957, 0.74514744, 0.32877408,
#        0.6893514 , 0.16281051, 0.76660756, 0.81486774, 0.24226391,
#        0.29485803, 0.63968343, 0.51565225, 0.93799591, 0.69873754,
#        0.51413615, 0.8778149 , 0.55383523, 0.27703098, 0.4698192 ,
#        0.07004532, 0.25279436, 0.20510339, 0.35205524, 0.87378541,
#        0.46300706, 0.62411661, 0.25910873, 0.36656156, 0.80958619,
#        0.35054051, 0.4773386 , 0.37933614, 0.00370548, 0.50896362,
#        0.26276812, 0.16219346, 0.64452325, 0.45178514, 0.4878851 ,
#        0.43223661, 0.85196856, 0.34084905, 0.57839961, 0.83493343,
#        0.92322361, 0.56900303, 0.65718918, 0.10662942, 0.61543963,
#        0.65433549, 0.92224983, 0.35277336, 0.57784546, 0.60517164,
#        0.96248609, 0.58878932, 0.52127989, 0.58382133, 0.97025671,
#        0.43688986, 0.80784823, 0.83051836, 0.83734481, 0.25683756,
#        0.17486244, 0.79211192, 0.03881672, 0.54954155, 0.3423962 ,
#        0.53437041, 0.65134961, 0.68047006, 0.19913502, 0.3182264 ,
#        0.00554361, 0.44573323, 0.82671891, 0.84481025, 0.98316728,
#        0.54185181, 0.20384004, 0.90455895, 0.63314535, 0.47063868,
#        0.52481849, 0.02431095, 0.8712469 , 0.24652396, 0.43563629,
#        0.02705374, 0.3386573 , 0.50955669, 0.56580878, 0.81611394])

# %%
X_normal = rng.normal(size=100)
X_normal
# Out:
# array([-0.3651814 , -0.834335  , -1.03071062, -1.9163435 ,  0.69147845,
#        -1.17178622, -0.92616023,  1.0236741 , -0.35493074, -1.51414886,
#         1.00263303,  1.40086184, -0.59291643, -0.57581971, -0.98734009,
#        -1.48437974, -2.12363587, -0.95750087, -0.44093921,  1.25377494,
#        -0.12909858, -0.75175576, -1.24249848,  1.58847703, -1.38902114,
#        -0.37339086,  1.32489659, -0.10620543,  0.75911099,  0.37314913,
#        -0.15536876, -0.72933275, -0.31215349,  0.91422456,  0.71586198,
#        -1.05624633,  0.12003174, -1.21433342, -0.1489189 , -0.93017855,
#        -1.12373007,  1.90124753, -0.96518032, -0.07207171,  0.11317304,
#         1.04166403,  1.10942951, -0.98446962, -0.09107876, -0.25500034,
#         0.48289509,  0.07860267,  0.30177956, -1.10123147, -0.3971634 ,
#         0.09422031,  0.42305362,  0.72989541,  0.91705229,  2.44175065,
#        -0.25548783,  1.23232507,  0.24517242,  1.94778083,  0.67822587,
#        -0.2393399 , -0.68266369,  0.9596886 ,  0.49912403, -0.13930497,
#        -0.27405516, -0.88057858,  0.63657831, -2.09265894, -0.68727041,
#        -1.01291446, -0.26489702,  0.42390682,  0.20858882, -0.8407208 ,
#         0.73408803,  1.44528803, -0.19695257,  2.1451991 , -0.94140781,
#         0.20728934, -0.97605765, -0.09759764,  0.79971693,  1.65057697,
#         3.83747019,  0.38197128,  0.75150092,  0.09619478, -0.3620262 ,
#         1.77793583,  0.60746152, -0.25767997,  0.01104633, -0.33923819])

# %%
X_binomial = rng.binomial(n=10, p=.3, size=100)
X_binomial
# Out:
# array([1, 2, 3, 3, 5, 4, 2, 4, 7, 2, 5, 4, 2, 4, 2, 5, 1, 2, 4, 5, 1, 1,
#        2, 7, 3, 3, 3, 5, 2, 0, 2, 3, 4, 4, 1, 3, 3, 3, 3, 3, 3, 2, 1, 3,
#        2, 4, 3, 1, 2, 3, 4, 4, 3, 3, 4, 3, 2, 2, 3, 1, 3, 3, 3, 4, 1, 2,
#        4, 1, 4, 5, 2, 3, 4, 4, 3, 6, 2, 1, 2, 3, 4, 5, 1, 4, 4, 4, 2, 4,
#        3, 2, 2, 3, 3, 5, 4, 1, 5, 3, 4, 2])

# %%
X_neg_binomial = rng.negative_binomial(n=10, p=.3, size=100)
X_neg_binomial
# Out:
# array([27, 32, 20, 34, 40, 26, 22, 24, 22, 26, 50, 28, 24, 30, 17, 35, 34,
#        21, 12, 24, 25, 11, 28, 14, 15, 21, 22, 24, 24, 45, 27, 32, 32, 39,
#         7, 24, 20, 16, 29, 36, 15, 22, 16, 17, 20, 37, 20, 24, 12, 34, 21,
#        17, 13, 15, 15, 15, 29, 33, 11, 33, 18, 14, 14, 26, 29, 19, 18, 16,
#        26, 13, 17, 19, 16, 21, 22, 33, 25, 32, 39, 11, 18, 16, 13, 41, 24,
#        14, 19, 16, 20, 24, 27, 20, 26, 21, 22, 11, 17, 43, 12, 25])

# %%
X_gamma = rng.gamma(shape=1.0, scale=0.9, size=100)
X_gamma
# Out:
# array([1.41566017, 0.81073581, 0.94611881, 0.12512147, 0.29662158,
#        0.67563616, 0.77773427, 0.86277575, 0.03229245, 1.93063067,
#        0.23723016, 1.29113251, 7.20280729, 1.69006336, 0.12466674,
#        1.0274833 , 2.73069003, 0.01778614, 0.6582926 , 2.27297398,
#        2.02532107, 1.03802588, 0.86344499, 0.25043511, 0.79824835,
#        3.41332757, 1.43111058, 1.24337342, 1.69336244, 1.71755659,
#        0.27908918, 2.04221237, 0.63585178, 0.31919823, 0.09865453,
#        0.88076281, 0.96319015, 1.83414296, 0.01920908, 1.12395596,
#        0.2969961 , 2.35374563, 2.33185314, 0.96223198, 0.43050339,
#        0.59431028, 0.05886911, 1.13666136, 0.79275615, 0.28223821,
#        3.5847512 , 0.05079361, 0.73221173, 0.56605459, 0.43117203,
#        7.0740067 , 0.2247    , 0.87902335, 3.62856906, 1.65422799,
#        0.2541512 , 0.26551161, 0.04293858, 0.38610367, 0.5417877 ,
#        0.06448032, 0.07132308, 0.37788213, 3.15870317, 0.37775444,
#        1.20280704, 0.46928841, 0.09081146, 0.73335701, 1.20667557,
#        1.45590584, 0.51564747, 0.99185417, 0.87729691, 0.1773779 ,
#        0.69645511, 0.14446817, 0.35239703, 0.44035416, 1.04732753,
#        0.61975058, 0.96403658, 0.27818655, 0.47013631, 1.10158633,
#        0.4132544 , 3.23275324, 1.7650038 , 0.30906082, 0.17202406,
#        0.25555488, 0.04342412, 0.52904309, 0.07085261, 1.26430573])

# %%
X_geom = rng.geometric(p=0.31, size=100)
X_geom
# Out:
# array([ 3,  7,  2,  6,  1,  3, 11,  2,  2,  1,  3,  2,  6,  1,  2,  1,  2,
#         2,  9,  6,  2,  5,  4,  6,  6,  1,  7,  1,  3,  2,  4,  5,  4,  1,
#         3,  1,  4,  3,  3,  1,  7,  1,  8,  1,  1,  7,  3,  5,  2,  6,  1,
#         1,  5,  1,  1,  4,  4,  1,  4,  2,  1,  5,  3,  2,  2,  2,  1,  6,
#         8,  1,  2,  3,  3,  2,  3,  2,  2,  3,  4,  2,  1,  3,  4,  3,  7,
#         1,  1,  2,  1,  2,  2,  7,  2,  1,  1,  6,  1,  1,  1,  2])

# %% [markdown]
# # Exercise 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, axes = plt.subplots(3, 3, figsize = (12, 8))
arrays = [X_int, X_uniform, X_normal, X_binomial, X_neg_binomial, X_gamma, X_geom]
axes = axes.flatten()
titles = ["Uniform Integer", "Uniform", "Normal", "Binomial", "Negative Binomial", "Gamma", "Geometric"]

for ax, arr, title in zip(axes, arrays, titles):
    counts, bin_edges = np.histogram(arr, bins=20)
    sns.histplot(arr, bins=20, ax=ax, alpha=0.6)
    ax.set_title(title)

    cumulative = np.cumsum(counts)
    bin_centers = (bin_edges[:-1] + bin_edges[1:])/2
    ax2 = ax.twinx()
    ax2.plot(bin_centers, cumulative, marker='o', color = 'red')
    ax.set_ylabel("Frequency")
    ax2.set_ylabel("Cumulative Frequency")

for ax in axes[len(arrays):]:
    ax.remove()

plt.tight_layout()
plt.show()
